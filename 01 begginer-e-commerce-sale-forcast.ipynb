# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/glove-global-vectors-for-word-representation/glove.6B.200d.txt
# /kaggle/input/glove-global-vectors-for-word-representation/glove.6B.50d.txt
# /kaggle/input/glove-global-vectors-for-word-representation/glove.6B.100d.txt
# /kaggle/input/ecommerce-data/data.csv

# %% [markdown]
# ## Warehouse optimization
# Within this kernel we will analyse sales data of an UK online retailer. As storage area may be expensive and fast delivery on time is important to prevail over the competition we like to help the retailer by predicting daily amounts of sold products.
#
# ## check dtypes

# %%
data = pd.read_csv('/kaggle/input/ecommerce-data/data.csv',  encoding="ISO-8859-1")

# %%
data.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
data['InvoiceDate'] = pd.to_datetime(data.InvoiceDate, cache= True)

# %%
data.InvoiceDate.max() - data.InvoiceDate.min()

print(f'first order took plance in {data.InvoiceDate.min()} and last one in {data.InvoiceDate.max()}')
# Out:
# first order took plance in 2010-12-01 08:26:00 and last one in 2011-12-09 12:50:00

# %%
data.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %% [markdown]
# ## EDA on dataset

# %%
data = pd.read_csv('/kaggle/input/ecommerce-data/data.csv', encoding="ISO-8859-1", dtype={'CustomerID': str})

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55      17850  United Kingdom
# 1  12/1/2010 8:26       3.39      17850  United Kingdom
# 2  12/1/2010 8:26       2.75      17850  United Kingdom
# 3  12/1/2010 8:26       3.39      17850  United Kingdom
# 4  12/1/2010 8:26       3.39      17850  United Kingdom
# 5  12/1/2010 8:26       7.65      17850  United Kingdom
# 6  12/1/2010 8:26       4.25      17850  United Kingdom
# 7  12/1/2010 8:28       1.85      17850  United Kingdom
# 8  12/1/2010 8:28       1.85      17850  United Kingdom
# 9  12/1/2010 8:34       1.69      13047  United Kingdom

# %%
#check for missing values percentage
data.isna().sum() / data.shape[0] * 100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %% [markdown]
# ## takeouts:
# almost 25% of the customerids are missing! Plus almost 2% of the products do not have any description! So now lelt's see which products misses description!

# %%
data[data.Description.isnull()].head()
# Out:
#      InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622     536414     22139         NaN        56  12/1/2010 11:52        0.0
# 1970    536545     21134         NaN         1  12/1/2010 14:32        0.0
# 1971    536546     22145         NaN         1  12/1/2010 14:33        0.0
# 1972    536547     37509         NaN         1  12/1/2010 14:33        0.0
# 1987    536549    85226A         NaN         1  12/1/2010 14:34        0.0
#
#      CustomerID         Country
# 622         NaN  United Kingdom
# 1970        NaN  United Kingdom
# 1971        NaN  United Kingdom
# 1972        NaN  United Kingdom
# 1987        NaN  United Kingdom

# %% [markdown]
# here we see that the ones that misses the description, does not also have the CustomerID, let's see how often this happens

# %%
#approach 1
len(data[(data['Description'].isnull()) & (data['CustomerID'].isnull())])

#approach 2
data[data.Description.isnull()].CustomerID.isnull().value_counts()
# Out:
# CustomerID
# True    1454
# Name: count, dtype: int64

# %%
(data[data.Description.isnull()].CustomerID.isnull() & (data['UnitPrice'] == 0)).value_counts()
# Out:
# False    540455
# True       1454
# Name: count, dtype: int64

# %% [markdown]
# ## takeout:
# for the products that are missing the description and customerid the unitprice is also missing, so In cases of missing descriptions we always miss the customer and the unit price as well. Why does the retailer records such kind of entries without a further description? It seems that there is no sophisticated procedure how to deal with and record such kind of transactions. This is already a hint that we could expect strange entries in our data and that it can be difficult to detect them!

# %% [markdown]
# ## Missing CustomerIDs

# %%
##missing customer ids
data[data.CustomerID.isnull()].head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                              NaN        56
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 622   12/1/2010 11:52       0.00        NaN  United Kingdom
# 1443  12/1/2010 14:32       2.51        NaN  United Kingdom
# 1444  12/1/2010 14:32       2.51        NaN  United Kingdom
# 1445  12/1/2010 14:32       0.85        NaN  United Kingdom
# 1446  12/1/2010 14:32       1.66        NaN  United Kingdom

# %%
data.loc[data.CustomerID.isnull(), ['UnitPrice', 'Quantity']].describe()
# Out:
#            UnitPrice       Quantity
# count  135080.000000  135080.000000
# mean        8.076577       1.995573
# std       151.900816      66.696153
# min    -11062.060000   -9600.000000
# 25%         1.630000       1.000000
# 50%         3.290000       1.000000
# 75%         5.450000       3.000000
# max     17836.460000    5568.000000

# %% [markdown]
# ## Takeouts:
# as you see in the UnitPrice, the mean is 9.07 while the max value found is 178300, so this sonuds like an outlier, right? similarliy for the Quantity. these all are in a way that the customer id is Null!!! so maybe a guess or so but we dont know! this becomes important especially if we wanna do some sort of analysis/featue engineering based on say historical shopping history say the historical prive and the sold quantity

# %%
data[data.Description.isnull()].head()
# Out:
#      InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622     536414     22139         NaN        56  12/1/2010 11:52        0.0
# 1970    536545     21134         NaN         1  12/1/2010 14:32        0.0
# 1971    536546     22145         NaN         1  12/1/2010 14:33        0.0
# 1972    536547     37509         NaN         1  12/1/2010 14:33        0.0
# 1987    536549    85226A         NaN         1  12/1/2010 14:34        0.0
#
#      CustomerID         Country
# 622         NaN  United Kingdom
# 1970        NaN  United Kingdom
# 1971        NaN  United Kingdom
# 1972        NaN  United Kingdom
# 1987        NaN  United Kingdom

# %% [markdown]
# now lets see in the Description col do we have any hidden nan values as well ? Meaning instead of Nan we have nan

# %%
#approach 1
data.loc[data.Description.isnull() == False, "lowercase-description"] = data.loc[data.Description.isnull() == False, "Description"].apply( lambda l:l.lower())

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice CustomerID         Country  \
# 0        12/1/2010 8:26       2.55      17850  United Kingdom
# 1        12/1/2010 8:26       3.39      17850  United Kingdom
# 2        12/1/2010 8:26       2.75      17850  United Kingdom
# 3        12/1/2010 8:26       3.39      17850  United Kingdom
# 4        12/1/2010 8:26       3.39      17850  United Kingdom
# ...                 ...        ...        ...             ...
# 541904  12/9/2011 12:50       0.85      12680          France
# 541905  12/9/2011 12:50       2.10      12680          France
# 541906  12/9/2011 12:50       4.15      12680          France
# 541907  12/9/2011 12:50       4.15      12680          France
# 541908  12/9/2011 12:50       4.95      12680          France
#
#                       lowercase-description
# 0        white hanging heart t-light holder
# 1                       white metal lantern
# 2            cream cupid hearts coat hanger
# 3       knitted union flag hot water bottle
# 4            red woolly hottie white heart.
# ...                                     ...
# 541904          pack of 20 spaceboy napkins
# 541905         children's apron dolly girl
# 541906        childrens cutlery dolly girl
# 541907      childrens cutlery circus parade
# 541908        baking set 9 piece retrospot
#
# [541909 rows x 9 columns]

# %%
data.rename(columns= {'lowercase-description':'lowercase_description'}, inplace=True)

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice CustomerID         Country  \
# 0        12/1/2010 8:26       2.55      17850  United Kingdom
# 1        12/1/2010 8:26       3.39      17850  United Kingdom
# 2        12/1/2010 8:26       2.75      17850  United Kingdom
# 3        12/1/2010 8:26       3.39      17850  United Kingdom
# 4        12/1/2010 8:26       3.39      17850  United Kingdom
# ...                 ...        ...        ...             ...
# 541904  12/9/2011 12:50       0.85      12680          France
# 541905  12/9/2011 12:50       2.10      12680          France
# 541906  12/9/2011 12:50       4.15      12680          France
# 541907  12/9/2011 12:50       4.15      12680          France
# 541908  12/9/2011 12:50       4.95      12680          France
#
#                       lowercase_description
# 0        white hanging heart t-light holder
# 1                       white metal lantern
# 2            cream cupid hearts coat hanger
# 3       knitted union flag hot water bottle
# 4            red woolly hottie white heart.
# ...                                     ...
# 541904          pack of 20 spaceboy napkins
# 541905         children's apron dolly girl
# 541906        childrens cutlery dolly girl
# 541907      childrens cutlery circus parade
# 541908        baking set 9 piece retrospot
#
# [541909 rows x 9 columns]

# %%
data.lowercase_description.dropna().apply(lambda l: np.where("nan" == l, True, False)).value_counts()
# if you pu "nan" in l, it will treat it as substring ; banana will be counted as NaN which is not our target!
# Out:
# lowercase_description
# False    540455
# Name: count, dtype: int64

# %%
#check for empty string
data.lowercase_description.dropna().apply(lambda l: np.where("" == l, True, False)).value_counts()
# Out:
# lowercase_description
# False    540455
# Name: count, dtype: int64

# %%
# transform nan ----> NaN  ## this is str treatment
data.loc[data.lowercase_description.isnull() == False, 'lowercase_description'] = data.loc[data.lowercase_description.isnull() == False].apply(lambda l: np.where("nan" in l, None, l))

# %%
data.isnull().sum().sum()
# Out:
# 137988

# %%
rows_with_nan_description = data[data['lowercase_description'].notnull() & data['lowercase_description'].str.contains("nan")]

# %%
rows_with_nan_description
# Out:
#        InvoiceNo StockCode                 Description  Quantity  \
# 5283      536856     22621  TRADITIONAL KNITTING NANCY        12
# 5918      536876     22621  TRADITIONAL KNITTING NANCY         1
# 7634      537049     21626  VINTAGE UNION JACK PENNANT        12
# 10328     537237     21626  VINTAGE UNION JACK PENNANT         1
# 10928     537240     22621  TRADITIONAL KNITTING NANCY         5
# ...          ...       ...                         ...       ...
# 539206    581438     22621  TRADITIONAL KNITTING NANCY        12
# 539649    581439     22621  TRADITIONAL KNITTING NANCY         3
# 540099    581467     22621  TRADITIONAL KNITTING NANCY         4
# 540970    581492     22621  TRADITIONAL KNITTING NANCY         2
# 541766    581574     22621  TRADITIONAL KNITTING NANCY        12
#
#             InvoiceDate  UnitPrice CustomerID         Country  \
# 5283    12/3/2010 10:26       1.45      13370  United Kingdom
# 5918    12/3/2010 11:36       1.45        NaN  United Kingdom
# 7634    12/5/2010 11:04       1.95      16241  United Kingdom
# 10328    12/6/2010 9:58       4.21        NaN  United Kingdom
# 10928   12/6/2010 10:08       1.45        NaN  United Kingdom
# ...                 ...        ...        ...             ...
# 539206  12/8/2011 16:29       1.65      12955  United Kingdom
# 539649  12/8/2011 16:30       3.29        NaN  United Kingdom
# 540099  12/8/2011 19:24       1.65      13077  United Kingdom
# 540970  12/9/2011 10:03       3.29        NaN  United Kingdom
# 541766  12/9/2011 12:09       1.65      12526         Germany
#
#              lowercase_description
# 5283    traditional knitting nancy
# 5918    traditional knitting nancy
# 7634    vintage union jack pennant
# 10328   vintage union jack pennant
# 10928   traditional knitting nancy
# ...                            ...
# 539206  traditional knitting nancy
# 539649  traditional knitting nancy
# 540099  traditional knitting nancy
# 540970  traditional knitting nancy
# 541766  traditional knitting nancy
#
# [731 rows x 9 columns]

# %%
data.dtypes
# Out:
# InvoiceNo                 object
# StockCode                 object
# Description               object
# Quantity                   int64
# InvoiceDate               object
# UnitPrice                float64
# CustomerID                object
# Country                   object
# lowercase_description     object
# dtype: object

# %%
# how many unique invoice num we have?
data.InvoiceDate.nunique()
# Out:
# 23260

# %% [markdown]
# ## invoice Date

# %%
data.dtypes
# Out:
# InvoiceNo                 object
# StockCode                 object
# Description               object
# Quantity                   int64
# InvoiceDate               object
# UnitPrice                float64
# CustomerID                object
# Country                   object
# lowercase_description     object
# dtype: object

# %%
data['InvoiceDate'] =  pd.to_datetime(data.InvoiceDate, cache= True)

# %%
data.dtypes
# Out:
# InvoiceNo                        object
# StockCode                        object
# Description                      object
# Quantity                          int64
# InvoiceDate              datetime64[ns]
# UnitPrice                       float64
# CustomerID                       object
# Country                          object
# lowercase_description            object
# dtype: object

# %%
print(f'the first order was place in {data.InvoiceDate.min()} and the last one on {data.InvoiceDate.max()}')
# Out:
# the first order was place in 2010-12-01 08:26:00 and the last one on 2011-12-09 12:50:00

# %% [markdown]
# ## invoice number

# %% [markdown]
# in the description they said the order were cancelled if there is a "C" in fornt of their invoice Num, so let's look at them...

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country  \
# 0      2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1      2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2      2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3      2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4      2010-12-01 08:26:00       3.39      17850  United Kingdom
# ...                    ...        ...        ...             ...
# 541904 2011-12-09 12:50:00       0.85      12680          France
# 541905 2011-12-09 12:50:00       2.10      12680          France
# 541906 2011-12-09 12:50:00       4.15      12680          France
# 541907 2011-12-09 12:50:00       4.15      12680          France
# 541908 2011-12-09 12:50:00       4.95      12680          France
#
#                       lowercase_description
# 0        white hanging heart t-light holder
# 1                       white metal lantern
# 2            cream cupid hearts coat hanger
# 3       knitted union flag hot water bottle
# 4            red woolly hottie white heart.
# ...                                     ...
# 541904          pack of 20 spaceboy napkins
# 541905         children's apron dolly girl
# 541906        childrens cutlery dolly girl
# 541907      childrens cutlery circus parade
# 541908        baking set 9 piece retrospot
#
# [541909 rows x 9 columns]

# %%
#approach 1
data['canceled_order'] = data.InvoiceNo.str.startswith("C")

data['canceled_order'].value_counts() / data.shape[0] * 100 #percentage look
# Out:
# canceled_order
# False    98.286059
# True      1.713941
# Name: count, dtype: float64

# %%
# approach 2
data['IsCalncelled'] = np.where(data.InvoiceNo.apply(lambda l:l[0] == 'C'), True, False)
data.IsCalncelled.value_counts() / data.shape[0] * 100
# Out:
# IsCalncelled
# False    98.286059
# True      1.713941
# Name: count, dtype: float64

# %%
data.loc[data.IsCalncelled == True,['Quantity', 'UnitPrice']].describe()
# Out:
#            Quantity     UnitPrice
# count   9288.000000   9288.000000
# mean     -29.885228     48.393661
# std     1145.786965    666.600430
# min   -80995.000000      0.010000
# 25%       -6.000000      1.450000
# 50%       -2.000000      2.950000
# 75%       -1.000000      5.950000
# max       -1.000000  38970.000000

# %%
data = data.loc[data.IsCalncelled == False].copy()
data = data.drop('IsCalncelled', axis=1)

# %% [markdown]
# ## StockCodeas

# %%
#how many unique stock codes
data.StockCode.nunique()

# %%
data.StockCode.value_counts(ascending=False)
# Out:
# StockCode
# 85123A    2271
# 85099B    2115
# 22423     2022
# 47566     1707
# 20725     1595
#           ...
# 85110        1
# 85179B       1
# 90000C       1
# 90095        1
# 23843        1
# Name: count, Length: 4059, dtype: int64

# %%
ax = data.StockCode.value_counts().iloc[0:20].plot(kind='bar', title = 'most common stockcodes')
ax.set_xlabel('Stock Codes')
ax.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
stockcodes =  data.StockCode.value_counts().iloc[0:20]
stockcodes
# Out:
# StockCode
# 85123A    2271
# 85099B    2115
# 22423     2022
# 47566     1707
# 20725     1595
# 84879     1490
# 22197     1426
# 22720     1403
# 21212     1370
# 20727     1328
# 22383     1327
# 22457     1263
# 23203     1250
# 22386     1238
# 22469     1228
# 22086     1200
# 21931     1197
# 22411     1190
# 22382     1179
# 20728     1174
# Name: count, dtype: int64

# %%
# same w/ sns
plt.figure(figsize= (10,7))
sns.barplot(x = stockcodes.index,
            y = stockcodes.values, palette='pastel')
plt.xticks(rotation=60) # Rotate the x-axis labels for better readability
plt.ylabel('Counts')
plt.xlabel('Stock Code')
plt.title('Top 20 Most Common Stock Codes')
plt.show()

# %%
#lets see only the numeric values in this stock codes
def numeric_detect(l):
    return sum(1 for c in col if c.isdigit())

# %%
#For each element (which represents a stock code), it checks if the entire string consists only of digits (isdigit()). If it does, it counts it as 1.
#This code counts the number of stock codes that contain only digits, not the total number of numeric characters in all stock codes combined.
sum(1 for i in data.StockCode.tolist() if i.isdigit())
# Out:
# 478985

# %%
def count_numeric_chars(l):
    return sum(1 for c in l if c.isdigit())

data["StockCodeLength"] = data.StockCode.apply(lambda l: len(l))
data["nNumericStockCode"] = data.StockCode.apply(lambda l: count_numeric_chars(l))

# %%
numeric_chars_count = sum(sum(c.isdigit() for c in code) for code in data['StockCode'])
numeric_chars_count
